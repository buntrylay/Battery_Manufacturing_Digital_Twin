# %%
import json
import time
from datetime import datetime, timedelta
import random
import os

class MixingSimulation:
    def __init__(self):
        self.Volume = 200  # Total volume in Litres
        self.AM_ratio = 0.495
        self.PVDF_ratio = 0.05
        self.CB_ratio = 0.045
        self.NMP_ratio = 0.41

        # Density of each component (g/cm³)
        self.RHO_AM = 2.26
        self.RHO_CB = 1.8
        self.RHO_PVDF = 1.78
        self.RHO_NMP = 1

        # Empirical values of each component
        self.a = 0.85  # AM
        self.b = 2.2  # Binder
        self.c = 0.3  # CB
        self.s = -0.4 # Solvent

        # Initial component volumes
        self.NMP = self.NMP_ratio * self.Volume
        self.PVDF = 0
        self.CB = 0
        self.AM = 0

        self.results = []
        self.total_time = 0
        self.start_datetime = datetime.now()
        

    def run(self, step_percent=0.02, pause_sec=0.1):
        self._add_in_steps('PVDF', self.PVDF_ratio, step_percent, pause_sec, "PVDF")
        self._add_in_steps('CB', self.CB_ratio, step_percent, pause_sec, "Carbon Black")
        self._add_in_steps('AM', self.AM_ratio, step_percent, pause_sec, "Active Material")

    def _add_in_steps(self, component, ratio, step_percent, pause_sec, label):
        total_volume_to_add = ratio * self.Volume
        step_volume = step_percent * total_volume_to_add
        num_steps = int(1 / step_percent)

        last_saved_time = time.time()

        for _ in range(num_steps):
            self.total_time == 0
            setattr(self, component, getattr(self, component) + step_volume)

            timestamp = (self.start_datetime + timedelta(seconds=self.total_time)).isoformat()
            temperature = round(random.uniform(20, 25), 2)
            pressure = round(random.uniform(1, 2), 2)
            rpm = random.randint(300, 600)
            density = self._calculate_density()
            viscosity = self._calculate_viscosity()
            yield_stress = self._calculate_yield_stress()

            result = {
                "TimeStamp": timestamp,
                "Duration": self.total_time,
                "AM": round(self.AM, 3),
                "CB": round(self.CB, 3),
                "PVDF": round(self.PVDF, 3),
                "NMP": round(self.NMP, 3),
                "Temperature": temperature,
                "Pressure": pressure,
                "Speed (RPM)": rpm,
                "Density": round(density, 4),
                "Viscosity": round(viscosity, 2),
                "Yield Stress": round(yield_stress, 2)
            }
            self.results.append(result)

            now = time.time()
            if now - last_saved_time >= 0.1:
                os.makedirs("simulation_output", exist_ok=True)
                filename = f"simulation_output/result_at_{int(self.total_time)}s.json"
                try:
                    with open(filename, "w") as f:
                        json.dump(result, f, indent=4)
                except Exception as e:
                    print(f"Error writing result to file: {e}")
                last_saved_time = now
            self.total_time += 5
            time.sleep(pause_sec)

    def _calculate_density(self):
        m_NMP = self.NMP * self.RHO_NMP
        m_PVDF = self.PVDF * self.RHO_PVDF
        m_CB = self.CB * self.RHO_CB
        m_AM = self.AM * self.RHO_AM

        total_mass = m_NMP + m_PVDF + m_CB + m_AM
        total_volume = self.NMP + self.PVDF + self.CB + self.AM
        return total_mass / total_volume if total_volume > 0 else 0

    def _calculate_viscosity(self, max_solid_fraction=0.63, intrinsic_viscosity=3):
        total_volume = self.NMP + self.PVDF + self.CB + self.AM
        if total_volume == 0:
            return 0

        solid_volume = self.PVDF + self.CB + self.AM
        phi = solid_volume / total_volume
        if phi >= max_solid_fraction:
            phi = max_solid_fraction - 0.001

        try:
            viscosity = (1 - (phi / max_solid_fraction)) ** (-intrinsic_viscosity * max_solid_fraction)
            return viscosity * 0.017
        except Exception as e:
            print(f"Viscosity calculation error: {e}")
            return float('inf')

    def _calculate_yield_stress(self):
        m_NMP = self.NMP * self.RHO_NMP
        m_PVDF = self.PVDF * self.RHO_PVDF
        m_CB = self.CB * self.RHO_CB
        m_AM = self.AM * self.RHO_AM

        y_AM = self.a * m_AM
        y_PVDF = self.b * m_PVDF
        y_CB = self.c * m_CB
        y_NMP = self.s * m_NMP
        return y_NMP + y_PVDF + y_CB + y_AM

    def save_to_json(self, filename="simulation_output/final_results.json"):
        os.makedirs("simulation_output", exist_ok=True)
        try:
            with open(filename, "w") as f:
                json.dump(self.results, f, indent=4)
        except Exception as e:
            print(f"Failed to save final results: {e}")


if __name__ == "__main__":
    sim = MixingSimulation()
    sim.run()
    sim.save_to_json()

    in_viscosity = sim.results[-1]["Viscosity"]
    solidContent = (sim.results[-1]["AM"] + sim.results[-1]["CB"] + sim.results[-1]["PVDF"]) / (sim.results[-1]["NMP"] + sim.results[-1]["AM"] + sim.results[-1]["CB"] + sim.results[-1]["PVDF"]) 
    mSolvent = sim.results[-1]["NMP"]
    print(in_viscosity)
    print(solidContent)
# Out:
# 3.11
# 0.59

# %% [markdown]
#     Coating Process

# %%
#########COATING---PROCESS##########
import numpy as np
import random
import time
import numpy as np
import json
from datetime import datetime, timedelta

class CoatingSimulation:
    def __init__(self):
        # Variables from Mixing
        self.viscosity_pa = in_viscosity
        self.solid_content = solidContent  # fraction (e.g., 0.55 for 55%)

        # Parameters & possible Input
        self.coating_speed = 0.05  # m/s (0,05 - 5 m/s)
        self.gap_height = 200e-6  # meters (50e-6 to 300 e-6)
        self.flow_rate = 5e-6  # m³/s (Possibly fixed)
        self.coating_width = 0.5  # m (possibly fixed)
        self.K = 100  # Defect risk constant (10-100)
        self.base_std = 0.01  # Base standard deviation
        self.nominal_shear_rate = 500  # 1/s
        self.sample_points = 800

        # Time tracking
        self.start_time = datetime.now()
        self.total_time = 0

        # For storing output
        self.results = []

    def simulate(self, end_time=100, save_json=False, filename="coating_simulation.json"):
        """Simulate the coating process and log results."""
        for t in range(0, end_time + 1, 5):
            self.total_time = t
            shear_rate = self.calculate_shear_rate()
            viscosity = self.viscosity_pa
            wet_thickness = self.calculate_wet_thickness()
            dry_thickness = self.calculate_dry_thickness(wet_thickness)
            defect_risk = self.check_defect_risk(shear_rate, viscosity)
            uniformity_std = self.calculate_uniformity(shear_rate)

            result = {
                "timestamp": str(self.start_time + timedelta(seconds=t)),
                "duration": t,
                "shear_rate_1_per_s": round(shear_rate, 4),
                "viscosity_Pa_s": round(viscosity, 4),
                "wet_thickness_m": round(wet_thickness, 5),
                "dry_thickness_m": round(dry_thickness, 5),
                "defect_risk": defect_risk,
                "uniformity_std": round(uniformity_std, 4),
            }

            self.results.append(result)

            # Print to console (optional)
            print(json.dumps(result, indent=2))

            time.sleep(0.1)  # Simulated time delay

        if save_json:
            with open(filename, "w") as f:
                json.dump(self.results, f, indent=2)

    def calculate_shear_rate(self):
        return self.coating_speed / self.gap_height

    def calculate_wet_thickness(self):
        return self.flow_rate / (self.coating_speed * self.coating_width)

    def calculate_dry_thickness(self, wet_thickness):
        return wet_thickness * self.solid_content

    def check_defect_risk(self, shear_rate, viscosity):
        return (self.coating_speed / self.gap_height) > (self.K * viscosity)

    def calculate_uniformity(self, shear_rate):
        return self.base_std * (shear_rate / self.nominal_shear_rate)


# Run the simulation with example values
if __name__ == "__main__":
    sim = CoatingSimulation()
    sim.simulate(end_time=100, save_json=True)


    wet_thickness_coating = sim.results[-1]["wet_thickness_m"]
    print(wet_thickness_coating)
# Out:
# {
#   "timestamp": "2025-05-13 11:33:12.776666",
#   "duration": 0,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:17.776666",
#   "duration": 5,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:22.776666",
#   "duration": 10,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:27.776666",
#   "duration": 15,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:32.776666",
#   "duration": 20,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:37.776666",
#   "duration": 25,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:42.776666",
#   "duration": 30,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:47.776666",
#   "duration": 35,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:52.776666",
#   "duration": 40,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:33:57.776666",
#   "duration": 45,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:02.776666",
#   "duration": 50,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:07.776666",
#   "duration": 55,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:12.776666",
#   "duration": 60,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:17.776666",
#   "duration": 65,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:22.776666",
#   "duration": 70,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:27.776666",
#   "duration": 75,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:32.776666",
#   "duration": 80,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:37.776666",
#   "duration": 85,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:42.776666",
#   "duration": 90,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:47.776666",
#   "duration": 95,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# {
#   "timestamp": "2025-05-13 11:34:52.776666",
#   "duration": 100,
#   "shear_rate_1_per_s": 250.0,
#   "viscosity_Pa_s": 3.11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.00012,
#   "defect_risk": false,
#   "uniformity_std": 0.005
# }
# 0.0002

# %% [markdown]
# Drying Process

# %%
import json
import time
import os
from datetime import datetime, timedelta

class DryingSimulation:
    def __init__(self, web_speed):
        # Inputs from Coating
        self.wet_thickness = wet_thickness_coating                # m (coating)
        self.solid_content = solidContent      # fraction (e.g., 0.5) (Mixing)
        self.web_speed = web_speed                # m/s

        # Fixed Parameters
        self.coating_width = 0.5    # m
        self.h_air = 0.1            # m
        self.drying_length = 10     # m
        self.T_dry = 100            # °C
        self.V_air = 1.0            # m³/s
        self.H_air = 30             # % RH
        self.density = 1500         # slurry density (kg/m³)
        self.solvent_density = 800  # kg/m³
        self.k0 = 0.001             # base mass transfer coefficient (m/s)
        self.delta_t = 1            # time step (s)
        self.max_safe_evap_rate = 0.001           # kg/m²/s

        # Derived Constants
        self.mass_transfer_coeff = self.k0 * (self.V_air / (self.coating_width * self.h_air))
        self.C_surface = 1.0
        self.C_air = self.H_air / 100
        self.delta_dry = self.wet_thickness * self.solid_content
        self.M_solvent = self.wet_thickness * (1 - self.solid_content) * self.density  # kg/m²
        self.area = self.coating_width * 1  # Assume 1m length
        self.residence_time = self.drying_length / self.web_speed
        self.time_steps = int(self.residence_time / self.delta_t)

        # Time and Output
        self.total_time = 0
        self.start_time = datetime.now()
        self.results = []

    def simulate(self, save_json=False, filename="drying_output/drying_results.json"):
        os.makedirs("drying_output", exist_ok=True)

        for t in range(0, self.time_steps + 1, self.delta_t):
            self.total_time = t

            # Evaporation rate (kg/s)
            evap_rate = -self.mass_transfer_coeff * self.area * (self.C_surface - self.C_air)

            # Update solvent mass
            self.M_solvent -= (evap_rate / self.area) * self.delta_t
            if self.M_solvent < 0:
                self.M_solvent = 0

            # Update coating thickness
            delta_coat = self.delta_dry + (self.M_solvent / self.solvent_density)

            # Check defect risk
            defect_risk = abs(evap_rate / self.area) > self.max_safe_evap_rate

            result = {
                "timestamp": str(self.start_time + timedelta(seconds=t)),
                "duration": t,
                "wet_thickness_m": round(self.wet_thickness, 6),
                "dry_thickness_m": round(self.delta_dry, 6),
                "M_solvent_kg_m2": round(self.M_solvent, 6),
                "evaporation_rate_kg_s": round(evap_rate, 6),
                "coating_thickness_m": round(delta_coat, 6),
                "defect_risk": defect_risk
            }

            self.results.append(result)
            print(json.dumps(result, indent=2))

            if self.M_solvent == 0:
                break

            time.sleep(0.05)

        if save_json:
            with open(filename, "w") as f:
                json.dump(self.results, f, indent=2)


# Run the simulation with example values
if __name__ == "__main__":
    drying_sim = DryingSimulation(
        web_speed=0.1             # m/s from coating
    )
    drying_sim.simulate(save_json=True)
    
    delta_dry_drying = drying_sim.results[-1]["dry_thickness_m"]
# Out:
# {
#   "timestamp": "2025-05-13 11:36:01.707563",
#   "duration": 0,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.137,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000289,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:02.707563",
#   "duration": 1,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.151,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000307,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:03.707563",
#   "duration": 2,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.165,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000324,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:04.707563",
#   "duration": 3,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.179,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000342,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:05.707563",
#   "duration": 4,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.193,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000359,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:06.707563",
#   "duration": 5,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.207,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000377,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:07.707563",
#   "duration": 6,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.221,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000394,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:08.707563",
#   "duration": 7,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.235,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000412,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:09.707563",
#   "duration": 8,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.249,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000429,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:10.707563",
#   "duration": 9,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.263,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000447,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:11.707563",
#   "duration": 10,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.277,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000464,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:12.707563",
#   "duration": 11,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.291,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000482,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:13.707563",
#   "duration": 12,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.305,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000499,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:14.707563",
#   "duration": 13,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.319,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000517,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:15.707563",
#   "duration": 14,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.333,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000534,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:16.707563",
#   "duration": 15,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.347,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000552,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:17.707563",
#   "duration": 16,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.361,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000569,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:18.707563",
#   "duration": 17,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.375,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000587,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:19.707563",
#   "duration": 18,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.389,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000604,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:20.707563",
#   "duration": 19,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.403,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000622,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:21.707563",
#   "duration": 20,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.417,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000639,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:22.707563",
#   "duration": 21,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.431,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000657,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:23.707563",
#   "duration": 22,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.445,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000674,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:24.707563",
#   "duration": 23,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.459,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000692,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:25.707563",
#   "duration": 24,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.473,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000709,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:26.707563",
#   "duration": 25,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.487,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000727,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:27.707563",
#   "duration": 26,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.501,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000744,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:28.707563",
#   "duration": 27,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.515,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000762,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:29.707563",
#   "duration": 28,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.529,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000779,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:30.707563",
#   "duration": 29,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.543,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000797,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:31.707563",
#   "duration": 30,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.557,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000814,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:32.707563",
#   "duration": 31,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.571,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000832,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:33.707563",
#   "duration": 32,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.585,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000849,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:34.707563",
#   "duration": 33,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.599,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000867,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:35.707563",
#   "duration": 34,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.613,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000884,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:36.707563",
#   "duration": 35,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.627,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000902,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:37.707563",
#   "duration": 36,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.641,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000919,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:38.707563",
#   "duration": 37,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.655,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000937,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:39.707563",
#   "duration": 38,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.669,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000954,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:40.707563",
#   "duration": 39,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.683,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000972,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:41.707563",
#   "duration": 40,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.697,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.000989,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:42.707563",
#   "duration": 41,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.711,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001007,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:43.707563",
#   "duration": 42,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.725,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001024,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:44.707563",
#   "duration": 43,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.739,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001042,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:45.707563",
#   "duration": 44,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.753,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001059,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:46.707563",
#   "duration": 45,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.767,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001077,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:47.707563",
#   "duration": 46,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.781,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001094,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:48.707563",
#   "duration": 47,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.795,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001112,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:49.707563",
#   "duration": 48,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.809,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001129,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:50.707563",
#   "duration": 49,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.823,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001147,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:51.707563",
#   "duration": 50,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.837,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001164,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:52.707563",
#   "duration": 51,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.851,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001182,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:53.707563",
#   "duration": 52,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.865,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001199,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:54.707563",
#   "duration": 53,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.879,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001217,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:55.707563",
#   "duration": 54,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.893,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001234,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:56.707563",
#   "duration": 55,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.907,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001252,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:57.707563",
#   "duration": 56,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.921,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001269,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:58.707563",
#   "duration": 57,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.935,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001287,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:36:59.707563",
#   "duration": 58,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.949,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001304,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:00.707563",
#   "duration": 59,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.963,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001322,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:01.707563",
#   "duration": 60,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.977,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001339,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:02.707563",
#   "duration": 61,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 0.991,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001357,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:03.707563",
#   "duration": 62,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.005,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001374,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:04.707563",
#   "duration": 63,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.019,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001392,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:05.707563",
#   "duration": 64,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.033,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001409,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:06.707563",
#   "duration": 65,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.047,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001427,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:07.707563",
#   "duration": 66,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.061,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001444,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:08.707563",
#   "duration": 67,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.075,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001462,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:09.707563",
#   "duration": 68,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.089,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001479,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:10.707563",
#   "duration": 69,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.103,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001497,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:11.707563",
#   "duration": 70,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.117,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001514,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:12.707563",
#   "duration": 71,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.131,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001532,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:13.707563",
#   "duration": 72,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.145,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001549,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:14.707563",
#   "duration": 73,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.159,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001567,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:15.707563",
#   "duration": 74,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.173,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001584,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:16.707563",
#   "duration": 75,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.187,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001602,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:17.707563",
#   "duration": 76,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.201,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001619,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:18.707563",
#   "duration": 77,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.215,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001637,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:19.707563",
#   "duration": 78,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.229,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001654,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:20.707563",
#   "duration": 79,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.243,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001672,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:21.707563",
#   "duration": 80,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.257,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001689,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:22.707563",
#   "duration": 81,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.271,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001707,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:23.707563",
#   "duration": 82,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.285,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001724,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:24.707563",
#   "duration": 83,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.299,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001742,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:25.707563",
#   "duration": 84,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.313,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001759,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:26.707563",
#   "duration": 85,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.327,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001777,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:27.707563",
#   "duration": 86,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.341,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001794,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:28.707563",
#   "duration": 87,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.355,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001812,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:29.707563",
#   "duration": 88,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.369,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001829,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:30.707563",
#   "duration": 89,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.383,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001847,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:31.707563",
#   "duration": 90,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.397,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001864,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:32.707563",
#   "duration": 91,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.411,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001882,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:33.707563",
#   "duration": 92,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.425,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001899,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:34.707563",
#   "duration": 93,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.439,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001917,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:35.707563",
#   "duration": 94,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.453,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001934,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:36.707563",
#   "duration": 95,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.467,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001952,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:37.707563",
#   "duration": 96,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.481,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001969,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:38.707563",
#   "duration": 97,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.495,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.001987,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:39.707563",
#   "duration": 98,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.509,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.002004,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:40.707563",
#   "duration": 99,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.523,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.002022,
#   "defect_risk": true
# }
# {
#   "timestamp": "2025-05-13 11:37:41.707563",
#   "duration": 100,
#   "wet_thickness_m": 0.0002,
#   "dry_thickness_m": 0.000118,
#   "M_solvent_kg_m2": 1.537,
#   "evaporation_rate_kg_s": -0.007,
#   "coating_thickness_m": 0.002039,
#   "defect_risk": true
# }

# %%
####Calendaring####

class CalendaringProcess:
    def __init__(self):
        # Input from drying stage
        self.delta_dry = delta_dry_drying        # Dry coating thickness (m) ##Drying Process
        self.phi_initial = 0.4         # Initial porosity 
        
        ###Controlled Variables
        self.E = 500e6                 # Elastic modulus (Pa)
        self.k_p = 3.0                 # Porosity reduction constant
        
        ###User Input###
        self.h_roll = 60e-6            # Roll gap (m) ## 50e-6 - 500e-6
        self.P_roll = 50e6             # Applied roll pressure (Pa) ## 20e6, 50e6
        self.v_roll = 1.0              # Roll speed (m/s) ## 0.5 to 2
        
        # Environment
        self.T = 25                    # Temperature (°C) ##Fixed

        # Time
        self.delta_t = 1               # Time step (s)
        self.total_time = 60           # Total simulation time (s)

        self.start_time = datetime.now()
        self.results = []

    def epsilon(self):
        return (self.delta_dry - self.h_roll) / self.delta_dry

    def sigmaCalc(self, epsilon_val):
        return self.E * epsilon_val

    def porosityReduction(self, epsilon_val):
        return self.phi_initial * np.exp(-self.k_p * epsilon_val)

    def defectRisk(self, applied_sigma, calculated_sigma, time_step):
        if applied_sigma > 2 * calculated_sigma:
            msg = f"Warning: Excessive pressure at t = {time_step}s may cause cracks."
            return True, msg
        else:
            return False, ""

    def simulation(self, save_json=False, filename="calendaring_simulation.json"):
        # Initial calculations
        epsilon_val = self.epsilon()
        sigma_val = self.P_roll
        sigma_theory = self.sigmaCalc(epsilon_val)
        porosity = self.porosityReduction(epsilon_val)
        final_thick = self.h_roll

        # Simulation loop
        for t in range(0, self.total_time + 1, self.delta_t):
            # Update roll gap, speed, and pressure dynamically
            self.h_roll = 60e-6 * (1 - t / self.total_time)  # Decrease roll gap over time
            self.v_roll = max(0.5, 1.0 - t / (self.total_time * 2))  # Gradually reduce speed
            self.P_roll = 50e6 * (1 - self.h_roll / self.delta_dry)  # Increase pressure as roll gap decreases

            # Recalculate strain (epsilon) based on the updated roll gap
            epsilon_val = self.epsilon()
            sigma_theory = self.sigmaCalc(epsilon_val)
            porosity = self.porosityReduction(epsilon_val)
            final_thick = self.h_roll

            # Check for defect risk
            risk, warning_msg = self.defectRisk(sigma_val, sigma_theory, t)

            # Record results
            timestamp = self.start_time + timedelta(seconds=t)
            result = {
                "timestamp": str(timestamp),
                "time_elapsed_s": t,
                "gap": self.h_roll,
                "speed": self.v_roll,
                "pressure": self.P_roll,
                "strain_epsilon": round(epsilon_val, 6),
                "applied_pressure_Pa": sigma_val,
                "calculated_stress_Pa": round(sigma_theory, 2),
                "final_thickness_m": round(final_thick, 8),
                "porosity_after_calendaring": round(porosity, 4),
                "defect_risk": risk,
            }

            if warning_msg:
                result["warning"] = warning_msg

            self.results.append(result)
            print(json.dumps(result, indent=2))

            # Simulate real-time delay
            time.sleep(0.1)

        # Save results to JSON file if requested
        if save_json:
            with open(filename, "w") as f:
                json.dump(self.results, f, indent=2)
            print(f"\nSimulation results saved to {filename}")

# Run the simulation
if __name__ == "__main__":
    cal = CalendaringProcess()
    cal.simulation(save_json=True)
# Out:
# {
#   "timestamp": "2025-05-13 11:36:08.767139",
#   "time_elapsed_s": 0,
#   "gap": 6e-05,
#   "speed": 1.0,
#   "pressure": 24576271.186440673,
#   "strain_epsilon": 0.491525,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 245762711.86,
#   "final_thickness_m": 6e-05,
#   "porosity_after_calendaring": 0.0916,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:09.767139",
#   "time_elapsed_s": 1,
#   "gap": 5.9e-05,
#   "speed": 0.9916666666666667,
#   "pressure": 25000000.0,
#   "strain_epsilon": 0.5,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 250000000.0,
#   "final_thickness_m": 5.9e-05,
#   "porosity_after_calendaring": 0.0893,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:10.767139",
#   "time_elapsed_s": 2,
#   "gap": 5.8e-05,
#   "speed": 0.9833333333333333,
#   "pressure": 25423728.81355932,
#   "strain_epsilon": 0.508475,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 254237288.14,
#   "final_thickness_m": 5.8e-05,
#   "porosity_after_calendaring": 0.087,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:11.767139",
#   "time_elapsed_s": 3,
#   "gap": 5.6999999999999996e-05,
#   "speed": 0.975,
#   "pressure": 25847457.627118643,
#   "strain_epsilon": 0.516949,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 258474576.27,
#   "final_thickness_m": 5.7e-05,
#   "porosity_after_calendaring": 0.0848,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:12.767139",
#   "time_elapsed_s": 4,
#   "gap": 5.6e-05,
#   "speed": 0.9666666666666667,
#   "pressure": 26271186.440677963,
#   "strain_epsilon": 0.525424,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 262711864.41,
#   "final_thickness_m": 5.6e-05,
#   "porosity_after_calendaring": 0.0827,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:13.767139",
#   "time_elapsed_s": 5,
#   "gap": 5.5e-05,
#   "speed": 0.9583333333333334,
#   "pressure": 26694915.254237283,
#   "strain_epsilon": 0.533898,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 266949152.54,
#   "final_thickness_m": 5.5e-05,
#   "porosity_after_calendaring": 0.0806,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:14.767139",
#   "time_elapsed_s": 6,
#   "gap": 5.4000000000000005e-05,
#   "speed": 0.95,
#   "pressure": 27118644.067796603,
#   "strain_epsilon": 0.542373,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 271186440.68,
#   "final_thickness_m": 5.4e-05,
#   "porosity_after_calendaring": 0.0786,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:15.767139",
#   "time_elapsed_s": 7,
#   "gap": 5.3e-05,
#   "speed": 0.9416666666666667,
#   "pressure": 27542372.88135593,
#   "strain_epsilon": 0.550847,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 275423728.81,
#   "final_thickness_m": 5.3e-05,
#   "porosity_after_calendaring": 0.0766,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:16.767139",
#   "time_elapsed_s": 8,
#   "gap": 5.2000000000000004e-05,
#   "speed": 0.9333333333333333,
#   "pressure": 27966101.694915254,
#   "strain_epsilon": 0.559322,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 279661016.95,
#   "final_thickness_m": 5.2e-05,
#   "porosity_after_calendaring": 0.0747,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:17.767139",
#   "time_elapsed_s": 9,
#   "gap": 5.1e-05,
#   "speed": 0.925,
#   "pressure": 28389830.508474577,
#   "strain_epsilon": 0.567797,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 283898305.08,
#   "final_thickness_m": 5.1e-05,
#   "porosity_after_calendaring": 0.0728,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:18.767139",
#   "time_elapsed_s": 10,
#   "gap": 5e-05,
#   "speed": 0.9166666666666666,
#   "pressure": 28813559.3220339,
#   "strain_epsilon": 0.576271,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 288135593.22,
#   "final_thickness_m": 5e-05,
#   "porosity_after_calendaring": 0.071,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:19.767139",
#   "time_elapsed_s": 11,
#   "gap": 4.9e-05,
#   "speed": 0.9083333333333333,
#   "pressure": 29237288.13559322,
#   "strain_epsilon": 0.584746,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 292372881.36,
#   "final_thickness_m": 4.9e-05,
#   "porosity_after_calendaring": 0.0692,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:20.767139",
#   "time_elapsed_s": 12,
#   "gap": 4.8e-05,
#   "speed": 0.9,
#   "pressure": 29661016.94915254,
#   "strain_epsilon": 0.59322,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 296610169.49,
#   "final_thickness_m": 4.8e-05,
#   "porosity_after_calendaring": 0.0675,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:21.767139",
#   "time_elapsed_s": 13,
#   "gap": 4.7000000000000004e-05,
#   "speed": 0.8916666666666666,
#   "pressure": 30084745.76271186,
#   "strain_epsilon": 0.601695,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 300847457.63,
#   "final_thickness_m": 4.7e-05,
#   "porosity_after_calendaring": 0.0658,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:22.767139",
#   "time_elapsed_s": 14,
#   "gap": 4.6e-05,
#   "speed": 0.8833333333333333,
#   "pressure": 30508474.576271184,
#   "strain_epsilon": 0.610169,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 305084745.76,
#   "final_thickness_m": 4.6e-05,
#   "porosity_after_calendaring": 0.0641,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:23.767139",
#   "time_elapsed_s": 15,
#   "gap": 4.5e-05,
#   "speed": 0.875,
#   "pressure": 30932203.389830504,
#   "strain_epsilon": 0.618644,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 309322033.9,
#   "final_thickness_m": 4.5e-05,
#   "porosity_after_calendaring": 0.0625,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:24.767139",
#   "time_elapsed_s": 16,
#   "gap": 4.4000000000000006e-05,
#   "speed": 0.8666666666666667,
#   "pressure": 31355932.203389823,
#   "strain_epsilon": 0.627119,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 313559322.03,
#   "final_thickness_m": 4.4e-05,
#   "porosity_after_calendaring": 0.061,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:25.767139",
#   "time_elapsed_s": 17,
#   "gap": 4.3e-05,
#   "speed": 0.8583333333333334,
#   "pressure": 31779661.01694915,
#   "strain_epsilon": 0.635593,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 317796610.17,
#   "final_thickness_m": 4.3e-05,
#   "porosity_after_calendaring": 0.0594,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:26.767139",
#   "time_elapsed_s": 18,
#   "gap": 4.2e-05,
#   "speed": 0.85,
#   "pressure": 32203389.830508478,
#   "strain_epsilon": 0.644068,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 322033898.31,
#   "final_thickness_m": 4.2e-05,
#   "porosity_after_calendaring": 0.0579,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:27.767139",
#   "time_elapsed_s": 19,
#   "gap": 4.1e-05,
#   "speed": 0.8416666666666667,
#   "pressure": 32627118.644067798,
#   "strain_epsilon": 0.652542,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 326271186.44,
#   "final_thickness_m": 4.1e-05,
#   "porosity_after_calendaring": 0.0565,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:28.767139",
#   "time_elapsed_s": 20,
#   "gap": 4e-05,
#   "speed": 0.8333333333333334,
#   "pressure": 33050847.457627118,
#   "strain_epsilon": 0.661017,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 330508474.58,
#   "final_thickness_m": 4e-05,
#   "porosity_after_calendaring": 0.0551,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:29.767139",
#   "time_elapsed_s": 21,
#   "gap": 3.9e-05,
#   "speed": 0.825,
#   "pressure": 33474576.27118644,
#   "strain_epsilon": 0.669492,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 334745762.71,
#   "final_thickness_m": 3.9e-05,
#   "porosity_after_calendaring": 0.0537,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:30.767139",
#   "time_elapsed_s": 22,
#   "gap": 3.8e-05,
#   "speed": 0.8166666666666667,
#   "pressure": 33898305.084745765,
#   "strain_epsilon": 0.677966,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 338983050.85,
#   "final_thickness_m": 3.8e-05,
#   "porosity_after_calendaring": 0.0523,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:31.767139",
#   "time_elapsed_s": 23,
#   "gap": 3.7000000000000005e-05,
#   "speed": 0.8083333333333333,
#   "pressure": 34322033.89830508,
#   "strain_epsilon": 0.686441,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 343220338.98,
#   "final_thickness_m": 3.7e-05,
#   "porosity_after_calendaring": 0.051,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:32.767139",
#   "time_elapsed_s": 24,
#   "gap": 3.6e-05,
#   "speed": 0.8,
#   "pressure": 34745762.711864404,
#   "strain_epsilon": 0.694915,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 347457627.12,
#   "final_thickness_m": 3.6e-05,
#   "porosity_after_calendaring": 0.0497,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:33.767139",
#   "time_elapsed_s": 25,
#   "gap": 3.5e-05,
#   "speed": 0.7916666666666666,
#   "pressure": 35169491.52542373,
#   "strain_epsilon": 0.70339,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 351694915.25,
#   "final_thickness_m": 3.5e-05,
#   "porosity_after_calendaring": 0.0485,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:34.767139",
#   "time_elapsed_s": 26,
#   "gap": 3.4e-05,
#   "speed": 0.7833333333333333,
#   "pressure": 35593220.33898305,
#   "strain_epsilon": 0.711864,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 355932203.39,
#   "final_thickness_m": 3.4e-05,
#   "porosity_after_calendaring": 0.0473,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:35.767139",
#   "time_elapsed_s": 27,
#   "gap": 3.3e-05,
#   "speed": 0.775,
#   "pressure": 36016949.15254237,
#   "strain_epsilon": 0.720339,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 360169491.53,
#   "final_thickness_m": 3.3e-05,
#   "porosity_after_calendaring": 0.0461,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:36.767139",
#   "time_elapsed_s": 28,
#   "gap": 3.2e-05,
#   "speed": 0.7666666666666666,
#   "pressure": 36440677.9661017,
#   "strain_epsilon": 0.728814,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 364406779.66,
#   "final_thickness_m": 3.2e-05,
#   "porosity_after_calendaring": 0.0449,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:37.767139",
#   "time_elapsed_s": 29,
#   "gap": 3.0999999999999995e-05,
#   "speed": 0.7583333333333333,
#   "pressure": 36864406.77966102,
#   "strain_epsilon": 0.737288,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 368644067.8,
#   "final_thickness_m": 3.1e-05,
#   "porosity_after_calendaring": 0.0438,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:38.767139",
#   "time_elapsed_s": 30,
#   "gap": 3e-05,
#   "speed": 0.75,
#   "pressure": 37288135.59322034,
#   "strain_epsilon": 0.745763,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 372881355.93,
#   "final_thickness_m": 3e-05,
#   "porosity_after_calendaring": 0.0427,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:39.767139",
#   "time_elapsed_s": 31,
#   "gap": 2.8999999999999997e-05,
#   "speed": 0.7416666666666667,
#   "pressure": 37711864.40677966,
#   "strain_epsilon": 0.754237,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 377118644.07,
#   "final_thickness_m": 2.9e-05,
#   "porosity_after_calendaring": 0.0416,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:40.767139",
#   "time_elapsed_s": 32,
#   "gap": 2.8e-05,
#   "speed": 0.7333333333333334,
#   "pressure": 38135593.22033898,
#   "strain_epsilon": 0.762712,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 381355932.2,
#   "final_thickness_m": 2.8e-05,
#   "porosity_after_calendaring": 0.0406,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:41.767139",
#   "time_elapsed_s": 33,
#   "gap": 2.7e-05,
#   "speed": 0.725,
#   "pressure": 38559322.0338983,
#   "strain_epsilon": 0.771186,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 385593220.34,
#   "final_thickness_m": 2.7e-05,
#   "porosity_after_calendaring": 0.0396,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:42.767139",
#   "time_elapsed_s": 34,
#   "gap": 2.6000000000000002e-05,
#   "speed": 0.7166666666666667,
#   "pressure": 38983050.847457625,
#   "strain_epsilon": 0.779661,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 389830508.47,
#   "final_thickness_m": 2.6e-05,
#   "porosity_after_calendaring": 0.0386,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:43.767139",
#   "time_elapsed_s": 35,
#   "gap": 2.4999999999999998e-05,
#   "speed": 0.7083333333333333,
#   "pressure": 39406779.66101695,
#   "strain_epsilon": 0.788136,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 394067796.61,
#   "final_thickness_m": 2.5e-05,
#   "porosity_after_calendaring": 0.0376,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:44.767139",
#   "time_elapsed_s": 36,
#   "gap": 2.4e-05,
#   "speed": 0.7,
#   "pressure": 39830508.47457627,
#   "strain_epsilon": 0.79661,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 398305084.75,
#   "final_thickness_m": 2.4e-05,
#   "porosity_after_calendaring": 0.0367,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:45.767139",
#   "time_elapsed_s": 37,
#   "gap": 2.3e-05,
#   "speed": 0.6916666666666667,
#   "pressure": 40254237.28813559,
#   "strain_epsilon": 0.805085,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 402542372.88,
#   "final_thickness_m": 2.3e-05,
#   "porosity_after_calendaring": 0.0357,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:46.767139",
#   "time_elapsed_s": 38,
#   "gap": 2.2000000000000003e-05,
#   "speed": 0.6833333333333333,
#   "pressure": 40677966.10169491,
#   "strain_epsilon": 0.813559,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 406779661.02,
#   "final_thickness_m": 2.2e-05,
#   "porosity_after_calendaring": 0.0348,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:47.767139",
#   "time_elapsed_s": 39,
#   "gap": 2.1e-05,
#   "speed": 0.675,
#   "pressure": 41101694.915254235,
#   "strain_epsilon": 0.822034,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 411016949.15,
#   "final_thickness_m": 2.1e-05,
#   "porosity_after_calendaring": 0.034,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:48.767139",
#   "time_elapsed_s": 40,
#   "gap": 2e-05,
#   "speed": 0.6666666666666667,
#   "pressure": 41525423.72881356,
#   "strain_epsilon": 0.830508,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 415254237.29,
#   "final_thickness_m": 2e-05,
#   "porosity_after_calendaring": 0.0331,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:49.767139",
#   "time_elapsed_s": 41,
#   "gap": 1.9e-05,
#   "speed": 0.6583333333333333,
#   "pressure": 41949152.54237288,
#   "strain_epsilon": 0.838983,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 419491525.42,
#   "final_thickness_m": 1.9e-05,
#   "porosity_after_calendaring": 0.0323,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:50.767139",
#   "time_elapsed_s": 42,
#   "gap": 1.8000000000000004e-05,
#   "speed": 0.65,
#   "pressure": 42372881.3559322,
#   "strain_epsilon": 0.847458,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 423728813.56,
#   "final_thickness_m": 1.8e-05,
#   "porosity_after_calendaring": 0.0315,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:51.767139",
#   "time_elapsed_s": 43,
#   "gap": 1.7e-05,
#   "speed": 0.6416666666666666,
#   "pressure": 42796610.16949152,
#   "strain_epsilon": 0.855932,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 427966101.69,
#   "final_thickness_m": 1.7e-05,
#   "porosity_after_calendaring": 0.0307,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:52.767139",
#   "time_elapsed_s": 44,
#   "gap": 1.6000000000000003e-05,
#   "speed": 0.6333333333333333,
#   "pressure": 43220338.983050846,
#   "strain_epsilon": 0.864407,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 432203389.83,
#   "final_thickness_m": 1.6e-05,
#   "porosity_after_calendaring": 0.0299,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:53.767139",
#   "time_elapsed_s": 45,
#   "gap": 1.5e-05,
#   "speed": 0.625,
#   "pressure": 43644067.79661017,
#   "strain_epsilon": 0.872881,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 436440677.97,
#   "final_thickness_m": 1.5e-05,
#   "porosity_after_calendaring": 0.0292,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:54.767139",
#   "time_elapsed_s": 46,
#   "gap": 1.3999999999999996e-05,
#   "speed": 0.6166666666666667,
#   "pressure": 44067796.61016949,
#   "strain_epsilon": 0.881356,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 440677966.1,
#   "final_thickness_m": 1.4e-05,
#   "porosity_after_calendaring": 0.0284,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:55.767139",
#   "time_elapsed_s": 47,
#   "gap": 1.3000000000000001e-05,
#   "speed": 0.6083333333333334,
#   "pressure": 44491525.42372881,
#   "strain_epsilon": 0.889831,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 444915254.24,
#   "final_thickness_m": 1.3e-05,
#   "porosity_after_calendaring": 0.0277,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:56.767139",
#   "time_elapsed_s": 48,
#   "gap": 1.1999999999999997e-05,
#   "speed": 0.6,
#   "pressure": 44915254.23728814,
#   "strain_epsilon": 0.898305,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 449152542.37,
#   "final_thickness_m": 1.2e-05,
#   "porosity_after_calendaring": 0.027,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:57.767139",
#   "time_elapsed_s": 49,
#   "gap": 1.1000000000000001e-05,
#   "speed": 0.5916666666666667,
#   "pressure": 45338983.050847456,
#   "strain_epsilon": 0.90678,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 453389830.51,
#   "final_thickness_m": 1.1e-05,
#   "porosity_after_calendaring": 0.0263,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:58.767139",
#   "time_elapsed_s": 50,
#   "gap": 9.999999999999997e-06,
#   "speed": 0.5833333333333333,
#   "pressure": 45762711.86440678,
#   "strain_epsilon": 0.915254,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 457627118.64,
#   "final_thickness_m": 1e-05,
#   "porosity_after_calendaring": 0.0257,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:36:59.767139",
#   "time_elapsed_s": 51,
#   "gap": 9.000000000000002e-06,
#   "speed": 0.575,
#   "pressure": 46186440.6779661,
#   "strain_epsilon": 0.923729,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 461864406.78,
#   "final_thickness_m": 9e-06,
#   "porosity_after_calendaring": 0.025,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:00.767139",
#   "time_elapsed_s": 52,
#   "gap": 7.999999999999998e-06,
#   "speed": 0.5666666666666667,
#   "pressure": 46610169.49152542,
#   "strain_epsilon": 0.932203,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 466101694.92,
#   "final_thickness_m": 8e-06,
#   "porosity_after_calendaring": 0.0244,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:01.767139",
#   "time_elapsed_s": 53,
#   "gap": 7.000000000000002e-06,
#   "speed": 0.5583333333333333,
#   "pressure": 47033898.30508474,
#   "strain_epsilon": 0.940678,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 470338983.05,
#   "final_thickness_m": 7e-06,
#   "porosity_after_calendaring": 0.0238,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:02.767139",
#   "time_elapsed_s": 54,
#   "gap": 5.9999999999999985e-06,
#   "speed": 0.55,
#   "pressure": 47457627.118644066,
#   "strain_epsilon": 0.949153,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 474576271.19,
#   "final_thickness_m": 6e-06,
#   "porosity_after_calendaring": 0.0232,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:03.767139",
#   "time_elapsed_s": 55,
#   "gap": 5.000000000000002e-06,
#   "speed": 0.5416666666666667,
#   "pressure": 47881355.93220339,
#   "strain_epsilon": 0.957627,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 478813559.32,
#   "final_thickness_m": 5e-06,
#   "porosity_after_calendaring": 0.0226,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:04.767139",
#   "time_elapsed_s": 56,
#   "gap": 3.999999999999999e-06,
#   "speed": 0.5333333333333333,
#   "pressure": 48305084.74576271,
#   "strain_epsilon": 0.966102,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 483050847.46,
#   "final_thickness_m": 4e-06,
#   "porosity_after_calendaring": 0.022,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:05.767139",
#   "time_elapsed_s": 57,
#   "gap": 3.0000000000000026e-06,
#   "speed": 0.525,
#   "pressure": 48728813.55932203,
#   "strain_epsilon": 0.974576,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 487288135.59,
#   "final_thickness_m": 3e-06,
#   "porosity_after_calendaring": 0.0215,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:06.767139",
#   "time_elapsed_s": 58,
#   "gap": 1.9999999999999995e-06,
#   "speed": 0.5166666666666666,
#   "pressure": 49152542.37288136,
#   "strain_epsilon": 0.983051,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 491525423.73,
#   "final_thickness_m": 2e-06,
#   "porosity_after_calendaring": 0.021,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:07.767139",
#   "time_elapsed_s": 59,
#   "gap": 1.0000000000000031e-06,
#   "speed": 0.5083333333333333,
#   "pressure": 49576271.18644068,
#   "strain_epsilon": 0.991525,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 495762711.86,
#   "final_thickness_m": 1e-06,
#   "porosity_after_calendaring": 0.0204,
#   "defect_risk": false
# }
# {
#   "timestamp": "2025-05-13 11:37:08.767139",
#   "time_elapsed_s": 60,
#   "gap": 0.0,
#   "speed": 0.5,
#   "pressure": 50000000.0,
#   "strain_epsilon": 1.0,
#   "applied_pressure_Pa": 50000000.0,
#   "calculated_stress_Pa": 500000000.0,
#   "final_thickness_m": 0.0,
#   "porosity_after_calendaring": 0.0199,
#   "defect_risk": false
# }
#
# Simulation results saved to calendaring_simulation.json
